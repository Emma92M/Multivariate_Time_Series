# %% [markdown]
# #*Chapter 4.4.2 Visualisation of the Corrected Images *
#
# #**Chapter 4.4.2**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install matplotlib==3.1.3

# %%
import pandas as pd
from sklearn import preprocessing
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt

# %%
rot_grid = pd.read_csv('/content/gdrive/MyDrive/Sent/new_grid.csv',  names = ['lat', 'lon'])

# %%
olf_file =  pd.read_csv('/content/gdrive/MyDrive/Sent/onsample_sep1.csv')

# %%
x = rot_grid['lat'].values.reshape(-1, 1) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(51.00006103515625,52.94684600830078))
x_scaled = min_max_scaler.fit_transform(x)
x_scaled

# %%
y = rot_grid['lon'].values.reshape(-1, 1) #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(12.000238,13.897455))
y_scaled = min_max_scaler.fit_transform(y)
y_scaled

# %%
matrix_aux = np.hstack([x_scaled,y_scaled])

df = pd.DataFrame(matrix_aux, columns =['latitude', 'longitude'])

df = df.sort_values(by=['latitude'], ascending=[False])

# %%
df['nitrogendioxide_tropospheric_column'] = olf_file_1['nitrogendioxide_tropospheric_column'].values

# %%
rot_g= np.array(rot_grid)

# %%
rot_g.max()
# Out:
# 20.249074919382007

# %%
scaler = sp.MinMaxScaler(feature_range=(12.000238418579102,52.94684600830078))
scaler = scaler.fit(rot_g)
scaled_mat= scaler.transform(rot_g)

# %%
geometry = [Point(xy) for xy in zip(olf_file['longitute'], olf_file['latitude'])]
gdf = GeoDataFrame(df, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(15, 6)), marker='o', color='red', markersize=15);

# %%
olf_file.plot(x="longitute", y="latitude", kind="scatter", c="nitrogendioxide_tropospheric_column",
        colormap="YlOrRd")

# %%
fig, ax = plt.subplots(figsize=(60,10))


countries = gpd.read_file(  
     gpd.datasets.get_path("naturalearth_lowres"))
countries[countries["name"] == "Germany"].plot(color="lightgrey",
                                                 ax=ax)

olf_file.plot(x="longitute", y="latitude", kind="scatter", 
        c="nitrogendioxide_tropospheric_column", colormap="YlOrRd", 
        title="No in Berlin", 
        ax=ax)
olf_file.plot(x="longitute", y="latitude", kind="scatter", c="nitrogendioxide_tropospheric_column",
        colormap="YlOrRd")
# add grid
ax.grid(b=True, alpha=0.5)
plt.show()

# %%
df.plot(x="longitude", y="latitude", kind="scatter", c="nitrogendioxide_tropospheric_column",
        colormap="YlOrRd")

# %%
# initialize an axis
fig, ax = plt.subplots(figsize=(60,10))
# plot map on axis
countries = gpd.read_file(  
     gpd.datasets.get_path("naturalearth_lowres"))
countries[countries["name"] == "Germany"].plot(color="lightgrey",
                                                 ax=ax)
# parse dates for plot's title

# plot points
df.plot(x="longitude", y="latitude", kind="scatter", 
        c="nitrogendioxide_tropospheric_column", colormap="YlOrRd", 
        title="No in Berlin", 
        ax=ax)
df.plot(x="longitude", y="latitude", kind="scatter", c="nitrogendioxide_tropospheric_column",
        colormap="YlOrRd")
# add grid
ax.grid(b=True, alpha=0.5)
plt.show()
