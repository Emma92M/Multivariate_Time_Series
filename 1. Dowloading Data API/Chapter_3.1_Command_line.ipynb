# %%
#2.Dowloading Data API/Command_line.ipynb

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install harp-image-preprocess
# !pip install sentinelsat

# %%
# !python /content/gdrive/MyDrive/Sent/download.py -c Berlin -f /content/gdrive/MyDrive/Sent/May20-Aug21 -l L2
